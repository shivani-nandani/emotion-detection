# %%
pip install dlib==19.3.1
# Out:
# ...
#      |████████████████████████████████| 4.0 MB 4.2 MB/s eta 0:00:01
# ...
#   ERROR: Command errored out with exit status 1:
#    command: /srv/conda/envs/saturn/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-6zmpzebg/dlib_93120b59266542b0a8e437a08d052f8a/setup.py'"'"'; __file__='"'"'/tmp/pip-install-6zmpzebg/dlib_93120b59266542b0a8e437a08d052f8a/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-a33qtw2i
#        cwd: /tmp/pip-install-6zmpzebg/dlib_93120b59266542b0a8e437a08d052f8a/
#   Complete output (20 lines):
#   running bdist_wheel
#   running build
#   Detected Python architecture: 64bit
#   Detected platform: linux
#   Configuring cmake ...
#   CMake Warning (dev) in CMakeLists.txt:
#     No project() command is present.  The top-level CMakeLists.txt file must
# ...

# %%
import face_detection
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
image = Image.open("../git-repos/emotion-detection/test_image.jpg")
image_array1 = np.array(image)
plt.imshow(image_array1)

# %%
image = face_recognition.load_image_file("../git-repos/emotion-detection/test_image.jpg")
face_locations = face_recognition.face_locations(image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-9f8ae41078c3> in <module>
# ----> 1 image = face_recognition.load_image_file("../git-repos/emotion-detection/test_image.jpg")
#       2 face_locations = face_recognition.face_locations(image)
#
# NameError: name 'face_recognition' is not defined
